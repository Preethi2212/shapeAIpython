# %%
# importing requests package
 
import requests     
 
 
def NewsFromBBC():
 
     
 
    # BBC news api
 
    # following query parameters are used
 
    # source, sortBy and apiKey
 
    query_params = {
 
      "source": "bbc-news",
 
      "sortBy": "top",
 
      "apiKey": "84037d3f850747fc9767cbf5e5ce1a0f"
 
    }
 
    main_url = " https://newsapi.org/v1/articles"
 
 
    # fetching data in json format
 
    res = requests.get(main_url, params=query_params)
 
    open_bbc_page = res.json()
 
 
    # getting all articles in a string article
 
    article = open_bbc_page["articles"]
 
 
    # empty list which will 
 
    # contain all trending news
 
    results = []
 
     
 
    for ar in article:
 
        results.append(ar["title"])
 
         
 
    for i in range(len(results)):
 
         
 
        # printing all trending news
 
        print(i + 1, results[i])
 
 
    #to read the news out loud for us
 
                  
 
# Driver Code
 
if __name__ == '__main__':
 
     
 
    # function call
 
    NewsFromBBC()
# Out:
# 1 'Heartbreaking' conditions in US migrant child camp
# 2 Senate Republicans block Democrats' election bill
# 3 Hong Kong's first trial under national security law starts without jury
# 4 Pentagon UFO report: Here's what we know
# 5 US government blocks Iran-affiliated news websites
# 6 ‘Heartless’ state bars family from dying father
# 7 Wall Street giant Morgan Stanley to bar unvaccinated staff
# 8 Spain pardons Catalan leaders over independence bid
# 9 Covid: Sydney faces new restrictions as cluster grows
# 10 UN Afghan envoy Deborah Lyons alarmed at Taliban gains
